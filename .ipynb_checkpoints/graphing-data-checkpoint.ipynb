# %%
import matplotlib.pyplot as plt
import csv

# %%
import matplotlib.pyplot as plt
import csv

qubits=[]
qpp=[]
pyquil=[]
cirq=[]
qiskit=[]

with open('grovers.csv', 'r') as csvfile:
    plots= csv.reader(csvfile, delimiter=',')
    for i in plots:
        print(i[0])
        qubits.append((i[0]))
        qpp.append((i[1]))
        pyquil.append((row[2]))
        cirq.append((row[3]))
        qiskit.append((row[4]))


plt.plot(qubits, qpp, marker='o')
#plt.plot(qubits, pyquil, marker='o')
#plt.plot(qubits, cirq, marker='o')
#plt.plot(qubits, qiskit, marker='o')


plt.title('Qubits vs. Time')

#plt.xlabel('Number of People')
#plt.ylabel('Expenses')

plt.show()
# Out:
# 2
# 4
# 6
# 8
# 10
